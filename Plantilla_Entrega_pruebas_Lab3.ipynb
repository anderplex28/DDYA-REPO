# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
Anderson Varela
Julian Sanchez

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
#
# Una tienda en Colombia necesita desarrollar un programa que calcule la menor cantidad de monedas necesarias para entregar un cambio determinado a un cliente.
#
# La tienda dispone de las siguientes monedas:
#
# monedas = [50, 100, 200, 500, 1000]
# El usuario deberá ingresar el valor del cambio que necesita entregar.
#
# Por ejemplo:
#
# Ingrese el valor del cambio: 1850
# El programa debe determinar cuál es la menor cantidad de monedas necesaria para completar exactamente ese valor.
#
# Una posible solución sería:
#
# 1000 + 500 + 200 + 100 + 50 = 1850
# Por lo tanto:
#
# Cantidad mínima de monedas: 5

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# Requerimientos Funcionales
#
# Recibir el monto del cambio como entrada
#
# Calcular la combinación óptima de monedas
#
# Mostrar la cantidad mínima de monedas
#
# Desglosar cuántas monedas de cada valor se usan
#
# Validar que el cambio sea múltiplo de 50
#
# Requerimientos No Funcionales
#
# Respuesta inmediata para cualquier monto válido
#
# Interfaz de texto clara y amigable
#
# Manejo de entradas inválidas con mensajes claros
#
# Algoritmo eficiente sin recursión innecesaria
#
# Código legible, mantenible y documentado

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
# Hist 1:
# El usuario quiere saber cual es la cantidad minima de monedas que puede devolver si necesita devolver 2000 pesos
#
# Criterios de aceptacion:Ingreso de un numero que cumpla con las especificaciones de la moneda colombiana,que no sean letras ni palabras,que no hayan simbolos dentro de lo que se ingresa junto a los datos
#
# Criterio de falla:El usuario añade una palabra o simbolo junto a los numeros por error
#
# Hist 2:
# Un empleado quiere saber como mejorar la distribucion de vueltas para ahorrar tiempo a la hora de vender productos asi que entra al programa y le mete una cantidad cualquiera
#
# CritACC:El numero es normal y sigue la moneda colombiana
#
# CritFALL:Letras, simbolos o numeros que no cumplan con la moneda colombiana

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# ![image.png](attachment:image.png)
#
# El usuario inicia el rpograma y este le pide que ingrese los datos de las vueltas y el programa valida que sean correctos los datos para continuar en caso de que sean incorrectos muestra error y pregunta si se desea continuar si sí reiniciamos todo y si no el programa termina de lo contrario si los datos son validos muestra la cantidad minimas de monedas y termina el programa

# %% [markdown]
# ## 5) Diagramas de secuencia **[5 pts]**
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6) Diagramas de casos de uso **[5 pts]**
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7) Análisis de complejidad **[5 pts]**
# Ecuacion :T(v)=v x 5
# Donde v es el valor ingresado y 5 son la cantidad de monedas que se pueden enregar y T es el tiempo total que le llevara al programa resolverlo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8) Código funcional **[10 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
monedas = [50, 100, 200, 500, 1000]

opcion = "s"

while opcion == "s":

    cambio = input("Ingrese el valor del cambio: ")

    if cambio.isdigit():
        cambio = int(cambio)

        dp = [float("inf")] * (cambio + 1)
        dp[0] = 0

        for i in range(1, cambio + 1):
            for moneda in monedas:
                if moneda <= i:
                    dp[i] = min(dp[i], dp[i - moneda] + 1)

        print("Cantidad mínima de monedas:", dp[cambio])

    else:
        print("Error: debe ingresar un número.")

    opcion = input("¿Desea continuar? (s/n): ")

print("Programa terminado.")
# Out:
# Cantidad mínima de monedas: 14
# Programa terminado.

# %% [markdown]
# ## 9) pruebas **[15 pts]**

# %%
def test(input, expected_output):
  # CALCULE LA SOLUCION (asignela a got_output)
  got_output =input
  assert got_output == expected_output, f"se obtuvo {got_output}, pero se esperaba {expected_output}"
  print(f"Paso caso de prueba {input} -> {expected_output}")

# %% [markdown]
# ## Pruebas de enunciado
#
# El programa debe determinar cuál es la menor cantidad de monedas necesaria para completar exactamente ese valor.
#
# Entrada usada.
#
# Ingrese el valor del cambio: 1850
#
# Salida esperada.
#
# Cantidad mínima de monedas: 5
#
# Salida obtenida.
#
# Cantidad mínima de monedas: 5

# %% [markdown]
# ## Pruebas propias
#
# El programa debe determinar cuál es la menor cantidad de monedas necesaria para completar exactamente ese valor.
#
# Entrada usada.
#
# Ingrese el valor del cambio: 10950
#
# Salida esperada.
#
# Cantidad mínima de monedas: 14
#
# Salida obtenida.
#
# Cantidad mínima de monedas: 14
#
#
#
# El programa debe determinar cuál es la menor cantidad de monedas necesaria para completar exactamente ese valor.
#
# Entrada usada.
#
# Ingrese el valor del cambio: Hola
#
# Salida esperada.
#
# Error debe ingresar un numero
#
# Salida obtenida.
#
# Error debe ingresar un numero

# %%
input, output = "123", "123"
test(input,output)
# Out:
# Paso caso de prueba 123 -> 123

# %% [markdown]
# ## Pruebas de Desempeño
# Qué va aquí?
#
# Medición empírica del tiempo de ejecución.
#
# Gráfica de comportamiento.
#
# Relación entre la gráfica obtenida y el análisis de complejidad teórico.
#
# #### Código base para benchmarking

# %%
# Calcula el tiempo de ejecucion con base a diferentes tamaños de la entrada
# y nos da una lista de resultados, cada resultado contiene el tamaño de la entrada
# y el tiempo de ejecucion
# TENER EN CUENTA ESTAS ENTRADAS PUEDEN VARIAR SEGÚN EL PROBLEMA


def bench(n: int, step: int = 1) -> list[tuple[int, float]]:
    print("Generando datos ...", end='')
    from random import randint
    import time
    results: list[tuple[int, float]] = []


    # AJUSTAR LAS ENTRADAS SEGÚN EL PROBLEMA
    for size in range(1, n, step):
        input = size

        ti = time.perf_counter()
        output = input # Ajustar a su función
        tf = time.perf_counter()


        delta = (tf - ti) * 1000
        print(".", end="")
        results.append((size, delta))
    return results


# === CODIGO PARA DIBUJAR ===


def dibujar(x, y, dimensiones=(7, 5)):
    assert len(x) == len(y)
    import matplotlib.pyplot as plt
    plt.figure(figsize=dimensiones)
    plt.plot(x, y)
    plt.show()


# === LLAMADO ===
tiempos = bench(10, step=1)


x = [size for size, timing in tiempos]
y = [timing for size, timing in tiempos]


dibujar(x, y)
# Out:
# Generando datos ............
