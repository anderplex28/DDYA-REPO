# %% [markdown]
# # DISEÑO DE DATOS Y ALGORITMOS

# %%
# @title Ingrese datos
nombre_estudiante = "" # @param {"type":"string"}
carnet = None # @param {"type":"integer"}

# %% [markdown]
# ## Enunciado
# ¿Qué va aquí?
#
# Ejercicio: Organización de precios en una tienda
# Una tienda necesita organizar los precios de sus productos. La cantidad de productos puede variar, por lo que el usuario deberá indicar cuántos precios desea registrar.
#
# El programa debe solicitar:
#
# La cantidad de productos, representada por n.
# El precio de cada uno de los productos.
# El tipo de ordenamiento que se desea mostrar.
# Después de ingresar los datos, el programa deberá utilizar el algoritmo Insertion Sort para organizar los precios.
#
# Punto 1. Orden ascendente
# Ordenar los precios desde el menor hasta el mayor, con el fin de mostrar primero los productos más económicos.
#
# Punto 2. Orden descendente
# Ordenar los precios desde el mayor hasta el menor, con el fin de mostrar primero los productos más costosos.
#
#
#
# Se debe entregar en la carpeta de git de la semana 2 haciendo uso de un PR con dos revisores
#
# https://teams.microsoft.com/l/entity/66aeee93-507d-479a-a3ef-8f494af43945/classroom?context=%7B%22subEntityId%22%3A%22%7B%5C%22version%5C%22%3A%5C%221.0%5C%22,%5C%22config%5C%22%3A%7B%5C%22classes%5C%22%3A%5B%7B%5C%22id%5C%22%3A%5C%2251942f7a-0809-401a-beae-b57e03fcfac4%5C%22,%5C%22assignmentIds%5C%22%3A%5B%5C%22c6307563-2206-4794-b339-cb897913622b%5C%22%5D%7D%5D%7D,%5C%22action%5C%22%3A%5C%22navigate%5C%22,%5C%22view%5C%22%3A%5C%22assignment-viewer%5C%22,%5C%22deeplinkType%5C%22%3A0%7D%22,%22channelId%22%3A%2219%3Apv8knfklvcOyJfwKscbt8Gma36PZCh4S3lJprNYXfw81@thread.tacv2%22%7D

# %% [markdown]
# # Especificacion

# %% [markdown]
# ¿Qué va aquí?
#
# Explique formalmente el problema usando el lenguaje de entradas y salidas.
#
# Entrada: Cantidad de productos  (Numeros)
# ReqFunc:Numeros
# ReqNoFun:Letras,Simbolos
#
# Entrada: Precios de Productos en desorden (Numeros y Simbolos sin superar la cantidad de productos priginal especificada)
# ReqFunc:Numeros,Simbolos
# ReqNoFun:Letras
#
# Entrada:Orden en el que se quiere recibir los precios (Letras)
# ReqFunc:Letras
# ReqNoFun:Numeros,Simbolos
#
# Salida:Lista de precios en orden ascendente o descendente dependiendo de lo que se pida (Numeros y Simbolos)

# %% [markdown]
# # Diseño
# ¿Qué va aquí?
#
# Vamos a programar un ejecutable en python el cual reciba la cantidad de productos precios y los organise en orden ascendente y descendente dependiendo de lo que pida el usuario usando merge sort en forma ascendente y descendente respectivamente guardando en listas se´paradas los precios originales y los organizados para solo devolver la lista organizada usando ciclos recursivos con el fin de hacer el proceso mas sencillo ademas de ser la solucion mas optima de resolverlo sin tener que repetir varias veces un solo subprograma sino llamando a cada uno en el momento indicado para cada uno
# Tabla de Costes:
# https://docs.google.com/document/d/1ZqTH4H_5q4L7sXOqJuv33qnLeCPd-J8NTTGVD-Zrtqc/edit?usp=sharing
#
# Peor caso:Color azul(El tiempo se va hacia el infinito)
#
# Mejor caso: Color verde(El tiempo apenas cambia sin importar los productos)
#
# ![image.png](attachment:image.png)
#
# Diagrama de Flujo:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Codigo
# ¿Qué va aquí?
#
# El código completo de la solución.
#
# Debe ser claro, legible y correctamente indentado.
#
# Use funciones bien nombradas.

# %%
# Julian Sanchez y Anderson Varela
def ingresar_precios(n):
    precios = []
    for i in range(n):
        precio = float(input(f"Ingrese el precio del producto {i + 1}: "))
        precios.append(precio)
    return precios
def insertion_sort_ascendente(precios):
    n = len(precios)
    for j in range(1, n):
        key = precios[j]
        i = j - 1
        while i >= 0 and precios[i] > key:
            precios[i + 1] = precios[i]
            i -= 1
        precios[i + 1] = key

def insertion_sort_descendente(precios):
    n = len(precios)
    for j in range(1, n):
        key = precios[j]
        i = j - 1
        while i >= 0 and precios[i] < key:
            precios[i + 1] = precios[i]
            i -= 1
        precios[i + 1] = key
def mostrar_precios(precios):
    print("\nPrecios ordenados:")
    for precio in precios:
        print(f"{precio:.2f} $")
def main():
    n = int(input("Ingrese la cantidad de productos: "))
    precios = ingresar_precios(n)
    print("\nTipo de ordenamiento")
    print("1. Ascendente")
    print("2. Descendente")
    opcion = int(input("Seleccione una opción: "))
    if opcion == 1:
        insertion_sort_ascendente(precios)
    elif opcion == 2:
        insertion_sort_descendente(precios)
    else:
        print("Opción no válida.")
        return
    mostrar_precios(precios)
main()
# Out:
# Tipo de ordenamiento
# 1. Ascendente
# 2. Descendente
#
# Precios ordenados:
# 3.00 $
# 2.00 $
# 1.00 $

# %% [markdown]
# # Pruebas

# %%
def test(input, expected_output):
  # CALCULE LA SOLUCION (asignela a got_output)
  got_output =input
  assert got_output == expected_output, f"se obtuvo {got_output}, pero se esperaba {expected_output}"
  print(f"Paso caso de prueba {input} -> {expected_output}")

# %% [markdown]
# ## Pruebas de enunciado
#
# ¿Qué va aquí?
#
# Casos de prueba proporcionados por el enunciado.
#
# Entrada usada.
#
# Salida esperada.
#
# Salida obtenida.

# %%
input, output = "123", "123"
test(input,output)
# Out:
# Paso caso de prueba 123 -> 123

# %% [markdown]
# ## Pruebas propias
# ¿Qué va aquí?
#
# Casos creados por usted.
#
# Casos tomados de [UDebug](https://www.udebug.com/) (si aplica).

# %%
input, output = "123", "123"
test(input,output)
# Out:
# Paso caso de prueba 123 -> 123

# %% [markdown]
# ## Pruebas de Desempeño
# Qué va aquí?
#
# Medición empírica del tiempo de ejecución.
#
# Gráfica de comportamiento.
#
# Relación entre la gráfica obtenida y el análisis de complejidad teórico.
#
# #### Código base para benchmarking

# %%
# Calcula el tiempo de ejecucion con base a diferentes tamaños de la entrada
# y nos da una lista de resultados, cada resultado contiene el tamaño de la entrada
# y el tiempo de ejecucion
# TENER EN CUENTA ESTAS ENTRADAS PUEDEN VARIAR SEGÚN EL PROBLEMA


def bench(n: int, step: int = 1) -> list[tuple[int, float]]:
    print("Generando datos ...", end='')
    from random import randint
    import time
    results: list[tuple[int, float]] = []


    # AJUSTAR LAS ENTRADAS SEGÚN EL PROBLEMA
    for size in range(1, n, step):  
        input = size

        ti = time.perf_counter()
        output = input # Ajustar a su función
        tf = time.perf_counter()


        delta = (tf - ti) * 1000
        print(".", end="")
        results.append((size, delta))
    return results


# === CODIGO PARA DIBUJAR ===


def dibujar(x, y, dimensiones=(7, 5)):
    assert len(x) == len(y)
    import matplotlib.pyplot as plt
    plt.figure(figsize=dimensiones)
    plt.plot(x, y)
    plt.show()


# === LLAMADO ===
tiempos = bench(10, step=1)


x = [size for size, timing in tiempos]
y = [timing for size, timing in tiempos]


dibujar(x, y)
# Out:
# Generando datos ............

# %% [markdown]
# ### Interpretación
#
# Explique:
#
# Qué comportamiento muestra la gráfica.
#
# Cómo se relaciona con su análisis de complejidad.

# %% [markdown]
# # Retrospectiva IA
# ¿Qué va aquí?
#
# Reflexión personal sobre el uso de IA:
#
# ¿En qué le ayudó la IA?
#
# ¿Qué parte del problema no entendía al inicio?
#
# ¿Qué aprendió realmente?
#
# No es una confesión, es una reflexión de aprendizaje.

# %% [markdown]
# # Juez
#
# ### Código Juez
#
# Incluya el código final enviado al juez, exactamente como se entregó:

# %%
#from sys import stdin

def main():
    pass


if __name__ == "__main__":
    main()

# %% [markdown]
# ### Evidencia Juez
# Capture de pantalla del resultado Accepted / Correct.
#
# Incluya claramente:
#
# Nombre del problema
#
# Estado
#
# Fecha (si es visible)
